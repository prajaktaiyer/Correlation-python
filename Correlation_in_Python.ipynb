# %% [markdown]
# ##Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# ##Read data from csv
# Dataset: https://www.kaggle.com/danielgrijalvas/movies

# %%
df = pd.read_csv('/content/movies.csv', encoding='latin-1')

# %% [markdown]
# ##Have a look at the data

# %%
df.head(5)
# Out:
#        budget                                 company  ...         writer  year
# 0   8000000.0           Columbia Pictures Corporation  ...   Stephen King  1986
# 1   6000000.0                      Paramount Pictures  ...    John Hughes  1986
# 2  15000000.0                      Paramount Pictures  ...       Jim Cash  1986
# 3  18500000.0  Twentieth Century Fox Film Corporation  ...  James Cameron  1986
# 4   9000000.0                    Walt Disney Pictures  ...  Mark H. Baker  1986
#
# [5 rows x 15 columns]

# %% [markdown]
# ##Data Cleaning and Formatting

# %%
#Check for missing data
for col in df.columns:
  percent_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col,percent_missing))
#no missing data
# Out:
# budget - 0.0%
# company - 0.0%
# country - 0.0%
# director - 0.0%
# genre - 0.0%
# gross - 0.0%
# name - 0.0%
# rating - 0.0%
# released - 0.0%
# runtime - 0.0%
# score - 0.0%
# star - 0.0%
# votes - 0.0%
# writer - 0.0%
# year - 0.0%

# %%
#Check data types for columns

df.dtypes
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime       int64
# score       float64
# star         object
# votes         int64
# writer       object
# year          int64
# dtype: object

# %%
#change data types

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
#Creating correct year of release column
df['correctyear'] =  df['released'].astype(str).str[:4] 
df

# %%
#Sorting records by gross income of movies
df.sort_values(by = ['gross'],inplace=False, ascending = False)

# %%
#Displaying all rows of the dataset
pd.set_option('display.max_rows',None)

# %%
#Drop duplicate data
df['company'].drop_duplicates().sort_values(ascending=False)

# %% [markdown]
# #Testing correlation between different variables

# %% [markdown]
# ###Numeric Variables

# %%
#Scatter plot with budget vs gross income

plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget vs Gross Income')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Income')
plt.show()

# %%
df.head(5)
# Out:
#      budget                                 company  ...  year correctyear
# 0   8000000           Columbia Pictures Corporation  ...  1986        1986
# 1   6000000                      Paramount Pictures  ...  1986        1986
# 2  15000000                      Paramount Pictures  ...  1986        1986
# 3  18500000  Twentieth Century Fox Film Corporation  ...  1986        1986
# 4   9000000                    Walt Disney Pictures  ...  1986        1986
#
# [5 rows x 16 columns]

# %%
#Plot Budget vs Gross Income using seaborn
sns.regplot(x='budget',y='gross', data=df,scatter_kws={'color':'black'},line_kws={'color':'purple'})

# %%
#pearson method
df.corr(method='pearson')
#High correlation between budget and gross income
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.712196  0.268226  0.042145  0.503924  0.291009
# gross    0.712196  1.000000  0.224579  0.165693  0.662457  0.191548
# runtime  0.268226  0.224579  1.000000  0.395343  0.317399  0.087639
# score    0.042145  0.165693  0.395343  1.000000  0.393607  0.105276
# votes    0.503924  0.662457  0.317399  0.393607  1.000000  0.229304
# year     0.291009  0.191548  0.087639  0.105276  0.229304  1.000000

# %% [markdown]
# ###Visualize using seaborn

# %%
#Visualize using seaborn
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)

plt.title('Correlation matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %% [markdown]
# ###Categorical Variables

# %%
#Looking at Categorical variables
#Company

# %%
#Changing object type data to category type 
df_numerized = df

for col_name in df_numerized.columns:
  if(df_numerized[col_name].dtype == 'object'):
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized.head

# %%
df_numerized.head(5)
# Out:
#      budget  company  country  director  ...   votes  writer  year  correctyear
# 0   8000000      665       54      2192  ...  299174    3716  1986            0
# 1   6000000     1680       54      1296  ...  264740    1970  1986            0
# 2  15000000     1680       54      2645  ...  236909    1852  1986            0
# 3  18500000     2062       54      1066  ...  540152    1629  1986            0
# 4   9000000     2122       54      2123  ...   36636    2549  1986            0
#
# [5 rows x 16 columns]

# %% [markdown]
# ###Visualize using seaborn

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)

plt.title('Correlation matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
# Out:
# Text(87.0, 0.5, 'Movie Features')

# %%
df_numerized.corr()
# Out:
#                budget   company   country  ...    writer      year  correctyear
# budget       1.000000  0.187205  0.137635  ... -0.015611  0.291009     0.274820
# company      0.187205  1.000000  0.107950  ... -0.004032  0.036272     0.028012
# country      0.137635  0.107950  1.000000  ...  0.024981 -0.045204    -0.062707
# director     0.011602  0.004320  0.003698  ...  0.298997 -0.000088     0.001822
# genre       -0.346794 -0.068330 -0.042793  ... -0.000608 -0.046259    -0.039014
# gross        0.712196  0.187220  0.149988  ... -0.009455  0.191548     0.176879
# name         0.028712  0.018098  0.025020  ...  0.009821  0.024624     0.023411
# rating      -0.119660 -0.062250  0.057979  ...  0.010740  0.016221     0.017438
# released     0.276635  0.027898 -0.062609  ... -0.004635  0.996187     0.999389
# runtime      0.268226  0.033058 -0.081796  ...  0.000759  0.087639     0.088342
# score        0.042145 -0.010426 -0.174414  ...  0.012223  0.105276     0.117679
# ...

# %%
corr_matrix = df_numerized.corr()
corr_pairs = corr_matrix.unstack()

# %%
corr_pairs
# Out:
# budget       budget         1.000000
#              company        0.187205
#              country        0.137635
#              director       0.011602
#              genre         -0.346794
#              gross          0.712196
#              name           0.028712
#              rating        -0.119660
#              released       0.276635
#              runtime        0.268226
#              score          0.042145
#              star          -0.015061
#              votes          0.503924
#              writer        -0.015611
#              year           0.291009
#              correctyear    0.274820
# company      budget         0.187205
#              company        1.000000
#              country        0.107950
#              director       0.004320
#              genre         -0.068330
#              gross          0.187220
#              name           0.018098
#              rating        -0.062250
#              released       0.027898
# ...

# %%
sorted_pairs = corr_pairs.sort_values()

# %%
sorted_pairs
# Out:
# genre        budget        -0.346794
# budget       genre         -0.346794
# gross        genre         -0.242676
# genre        gross         -0.242676
# score        country       -0.174414
# country      score         -0.174414
# votes        genre         -0.150519
# genre        votes         -0.150519
# rating       gross         -0.135538
# gross        rating        -0.135538
# budget       rating        -0.119660
# rating       budget        -0.119660
# country      runtime       -0.081796
# runtime      country       -0.081796
# genre        company       -0.068330
# company      genre         -0.068330
# country      correctyear   -0.062707
# correctyear  country       -0.062707
# country      released      -0.062609
# released     country       -0.062609
# rating       company       -0.062250
# company      rating        -0.062250
# year         genre         -0.046259
# genre        year          -0.046259
# country      year          -0.045204
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]
high_corr
# Out:
# votes        budget         0.503924
# budget       votes          0.503924
# votes        gross          0.662457
# gross        votes          0.662457
#              budget         0.712196
# budget       gross          0.712196
# released     year           0.996187
# year         released       0.996187
# correctyear  year           0.996229
# year         correctyear    0.996229
# correctyear  released       0.999389
# released     correctyear    0.999389
# budget       budget         1.000000
# writer       writer         1.000000
# votes        votes          1.000000
# star         star           1.000000
# score        score          1.000000
# runtime      runtime        1.000000
# released     released       1.000000
# rating       rating         1.000000
# name         name           1.000000
# gross        gross          1.000000
# genre        genre          1.000000
# director     director       1.000000
# country      country        1.000000
# ...

# %% [markdown]
# #Votes and Budget have the highest correlation to gross income
